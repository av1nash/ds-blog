# %% [markdown]
# # Parallel between SQL & Pandas
# > Introduction to Pandas by drawing parallel between SQL & Pandas
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [pandas,sql]
# - image: images/chart-preview.png

# %%
import pandas as pd

# %%
movies = 'https://vega.github.io/vega-datasets/data/movies.json'

# %% [markdown]
# ## SELECT
# In SQL, SELECT is the operation which allows you to explore and manipulate data.

# %% [markdown]
# ### Select all columns
# ```sql
# SELECT TOP 5 * FROM movies
# ```

# %%
df = pd.read_json(movies) # load movies data
df.head() # Shows top 5 rows by default, you can pass a value asking more than 5 rows like so - df.head(10)
# Out:
#                         Title   US Gross  Worldwide Gross  US DVD Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 3        Let's Talk About Sex   373615.0         373615.0           NaN
# 4                        Slam  1009819.0        1087521.0           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
# 3           300000.0  Sep 11 1998        None               NaN   Fine Line
# 4          1000000.0  Oct 09 1998           R               NaN     Trimark
#
#                 Source Major Genre         Creative Type Director  \
# 0                 None        None                  None     None
# 1                 None       Drama                  None     None
# 2                 None      Comedy                  None     None
# 3                 None      Comedy                  None     None
# 4  Original Screenplay       Drama  Contemporary Fiction     None
#
#    Rotten Tomatoes Rating  IMDB Rating  IMDB Votes
# 0                     NaN          6.1      1071.0
# 1                     NaN          6.9       207.0
# 2                     NaN          6.8       865.0
# 3                    13.0          NaN         NaN
# 4                    62.0          3.4       165.0

# %% [markdown]
# ### Select few columns
# ```sql
# SELECT TOP 5 Title, [IMDB Rating] FROM movies
# ```

# %%
df[['Title','IMDB Rating']].head()
# Out:
#                         Title  IMDB Rating
# 0              The Land Girls          6.1
# 1      First Love, Last Rites          6.9
# 2  I Married a Strange Person          6.8
# 3        Let's Talk About Sex          NaN
# 4                        Slam          3.4

# %% [markdown]
# ## WHERE
# ```sql
# SELECT * FROM movies WHERE [IMDB Rating] > 5
# ```

# %%
df[df['IMDB Rating'] > 5].head()
# Out:
#                         Title   US Gross  Worldwide Gross  US DVD Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 6                   Following    44705.0          44705.0           NaN
# 8                     Pirates  1641825.0        6341825.0           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
# 6             6000.0  Apr 04 1999           R               NaN   Zeitgeist
# 8         40000000.0  Jul 01 1986           R               NaN        None
#
#   Source Major Genre Creative Type           Director  Rotten Tomatoes Rating  \
# 0   None        None          None               None                     NaN
# 1   None       Drama          None               None                     NaN
# 2   None      Comedy          None               None                     NaN
# 6   None        None          None  Christopher Nolan                     NaN
# 8   None        None          None     Roman Polanski                    25.0
#
#    IMDB Rating  IMDB Votes
# 0          6.1      1071.0
# 1          6.9       207.0
# 2          6.8       865.0
# 6          7.7     15133.0
# 8          5.8      3275.0

# %% [markdown]
# ### WHERE - Logical operator AND
# ```sql
# SELECT * FROM movies WHERE [IMDB Rating] > 5 AND [MPAA Rating] = 'PG'
# ```

# %%
df[(df['IMDB Rating'] > 5) & (df['MPAA Rating']=='PG')].head()
# Out:
#                            Title    US Gross  Worldwide Gross  US DVD Sales  \
# 21                          1776         0.0              0.0           NaN
# 59   The Adventures of Huck Finn  24103594.0       24103594.0           NaN
# 67   Around the World in 80 Days  42000000.0       42000000.0           NaN
# 108           The Blue Butterfly   1610194.0        1610194.0           NaN
# 140                   The Basket    609042.0         609042.0           NaN
#
#      Production Budget Release Date MPAA Rating  Running Time min  \
# 21           4000000.0  Nov 09 1972          PG               NaN
# 59           6500000.0  Apr 02 1993          PG               NaN
# 67           6000000.0  Oct 17 1956          PG               NaN
# 108         10400000.0  Feb 20 2004          PG               NaN
# 140          1300000.0  May 05 2000          PG               NaN
#
#               Distributor                     Source Major Genre  \
# 21          Sony/Columbia              Based on Play       Drama
# 59   Walt Disney Pictures  Based on Book/Short Story   Adventure
# 67         United Artists  Based on Book/Short Story   Adventure
# 108              Alliance        Original Screenplay       Drama
# 140                   MGM        Original Screenplay       Drama
#
#             Creative Type         Director  Rotten Tomatoes Rating  \
# 21     Historical Fiction             None                    57.0
# 59     Historical Fiction  Stephen Sommers                    62.0
# 67                   None             None                    73.0
# 108  Contemporary Fiction             None                    44.0
# 140                  None             None                     NaN
#
#      IMDB Rating  IMDB Votes
# 21           7.0      4099.0
# 59           5.8      3095.0
# 67           5.6     21516.0
# 108          6.2       817.0
# 140          6.3       343.0

# %% [markdown]
# ### WHERE - Logical operator OR
# ```sql
# SELECT * FROM movies WHERE [MPAA Rating] = "PG" OR [MPAA Rating] = "PG-13"
# ```

# %%
df[(df['MPAA Rating'] == 'PG') | (df['MPAA Rating'] == 'PG-13')].head()
# Out:
#                              Title     US Gross  Worldwide Gross  \
# 21                            1776          0.0              0.0
# 31              3 Ninjas Kick Back   11744960.0       11744960.0
# 41                       The Abyss   54243125.0       54243125.0
# 43      Ace Ventura: Pet Detective   72217396.0      107217396.0
# 44  Ace Ventura: When Nature Calls  108360063.0      212400000.0
#
#     US DVD Sales  Production Budget Release Date MPAA Rating  \
# 21           NaN          4000000.0  Nov 09 1972          PG
# 31           NaN         20000000.0  May 06 1994          PG
# 41           NaN         70000000.0  Aug 09 1989       PG-13
# 43           NaN         12000000.0  Feb 04 1994       PG-13
# 44           NaN         30000000.0  Nov 10 1995       PG-13
#
#     Running Time min           Distributor               Source Major Genre  \
# 21               NaN         Sony/Columbia        Based on Play       Drama
# 31               NaN  Walt Disney Pictures  Original Screenplay      Action
# 41               NaN      20th Century Fox  Original Screenplay      Action
# 43               NaN          Warner Bros.  Original Screenplay      Comedy
# 44               NaN          Warner Bros.  Original Screenplay      Comedy
#
#            Creative Type        Director  Rotten Tomatoes Rating  IMDB Rating  \
# 21    Historical Fiction            None                    57.0          7.0
# 31  Contemporary Fiction            None                    17.0          3.2
# 41       Science Fiction   James Cameron                    88.0          7.6
# 43  Contemporary Fiction     Tom Shadyac                    49.0          6.6
# 44  Contemporary Fiction  Steve Oedekerk                     NaN          5.6
#
#     IMDB Votes
# 21      4099.0
# 31      3107.0
# 41     51018.0
# 43     63543.0
# 44     51275.0

# %% [markdown]
# ### WHERE - Logical operator NOT
# ```sql
# SELECT * FROM movies WHERE [Rotten Tomatoes Rating] IS NOT NULL
# ```

# %%
df[~df['Rotten Tomatoes Rating'].isnull()].head()
# Out:
#                    Title    US Gross  Worldwide Gross  US DVD Sales  \
# 3   Let's Talk About Sex    373615.0         373615.0           NaN
# 4                   Slam   1009819.0        1087521.0           NaN
# 8                Pirates   1641825.0        6341825.0           NaN
# 9        Duel in the Sun  20400000.0       20400000.0           NaN
# 10             Tom Jones  37600000.0       37600000.0           NaN
#
#     Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 3            300000.0  Sep 11 1998        None               NaN   Fine Line
# 4           1000000.0  Oct 09 1998           R               NaN     Trimark
# 8          40000000.0  Jul 01 1986           R               NaN        None
# 9           6000000.0  Dec 31 2046        None               NaN        None
# 10          1000000.0  Oct 07 1963        None               NaN        None
#
#                  Source Major Genre         Creative Type        Director  \
# 3                  None      Comedy                  None            None
# 4   Original Screenplay       Drama  Contemporary Fiction            None
# 8                  None        None                  None  Roman Polanski
# 9                  None        None                  None            None
# 10                 None        None                  None            None
#
#     Rotten Tomatoes Rating  IMDB Rating  IMDB Votes
# 3                     13.0          NaN         NaN
# 4                     62.0          3.4       165.0
# 8                     25.0          5.8      3275.0
# 9                     86.0          7.0      2906.0
# 10                    81.0          7.0      4035.0

# %% [markdown]
# ## GROUP BY
# ```sql
# SELECT [Major Genre],COUNT(*) FROM movies ORDER BY 2 DESC
# ```

# %%
df.groupby('Major Genre').size().sort_values(0,ascending=False)
# Out:
# <ipython-input-27-77301049b126>:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   df.groupby('Major Genre').size().sort_values(0,ascending=False)
# Major Genre
# Drama                  789
# Comedy                 675
# Action                 420
# Adventure              274
# Thriller/Suspense      239
# Horror                 219
# Romantic Comedy        137
# Musical                 53
# Documentary             43
# Black Comedy            36
# Western                 36
# Concert/Performance      5
# dtype: int64

# %% [markdown]
# ## JOIN
# JOINS are probably one of the most important operation in SQL, it allows you to combine two or more tables and perform operations on resulting dataset

# %%
data = [['Slam',5],['Pirates',8],['Duel in the Sun',7]]
df_favmovies = pd.DataFrame(data, columns=['my_fav_movies','my_rating'])

# %%
df_favmovies.head()
# Out:
#      my_fav_movies  my_rating
# 0             Slam          5
# 1          Pirates          8
# 2  Duel in the Sun          7

# %% [markdown]
# ### INNER JOIN
# ```sql
# SELECT m1.*,m2.*
# FROM movies m1
# INNER JOIN my_fav_movies m2
# ON m1.Title = m2.my_fav_movies
# ```

# %%
pd.merge(df,df_favmovies, left_on='Title', right_on='my_fav_movies', how='inner')
# Out:
#              Title    US Gross  Worldwide Gross  US DVD Sales  \
# 0             Slam   1009819.0        1087521.0           NaN
# 1          Pirates   1641825.0        6341825.0           NaN
# 2  Duel in the Sun  20400000.0       20400000.0           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 0          1000000.0  Oct 09 1998           R               NaN     Trimark
# 1         40000000.0  Jul 01 1986           R               NaN        None
# 2          6000000.0  Dec 31 2046        None               NaN        None
#
#                 Source Major Genre         Creative Type        Director  \
# 0  Original Screenplay       Drama  Contemporary Fiction            None
# 1                 None        None                  None  Roman Polanski
# 2                 None        None                  None            None
#
#    Rotten Tomatoes Rating  IMDB Rating  IMDB Votes    my_fav_movies  my_rating
# 0                    62.0          3.4       165.0             Slam          5
# 1                    25.0          5.8      3275.0          Pirates          8
# 2                    86.0          7.0      2906.0  Duel in the Sun          7

# %% [markdown]
# ### LEFT OUTER JOIN
# ```sql
# SELECT m1.*,m2.*
# FROM movies m1
# LEFT OUTER JOIN my_fav_movies m2
# ON m1.Title = m2.my_fav_movies
# ```

# %%
pd.merge(df,df_favmovies, left_on='Title', right_on='my_fav_movies', how='left').head()
# Out:
#                         Title   US Gross  Worldwide Gross  US DVD Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 3        Let's Talk About Sex   373615.0         373615.0           NaN
# 4                        Slam  1009819.0        1087521.0           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
# 3           300000.0  Sep 11 1998        None               NaN   Fine Line
# 4          1000000.0  Oct 09 1998           R               NaN     Trimark
#
#                 Source Major Genre         Creative Type Director  \
# 0                 None        None                  None     None
# 1                 None       Drama                  None     None
# 2                 None      Comedy                  None     None
# 3                 None      Comedy                  None     None
# 4  Original Screenplay       Drama  Contemporary Fiction     None
#
#    Rotten Tomatoes Rating  IMDB Rating  IMDB Votes my_fav_movies  my_rating
# 0                     NaN          6.1      1071.0           NaN        NaN
# 1                     NaN          6.9       207.0           NaN        NaN
# 2                     NaN          6.8       865.0           NaN        NaN
# 3                    13.0          NaN         NaN           NaN        NaN
# 4                    62.0          3.4       165.0          Slam        5.0
